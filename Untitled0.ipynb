# %% [markdown]
# <a href="https://colab.research.google.com/github/chandu2000711/Streamlit_Tutorial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas scikit-learn

# %%
pip install pandas scikit-learn joblib

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['species'] = iris.target

# %%
print(data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
X = data.drop(columns=['species'])
y = data['species']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%

# %%
import joblib

joblib.dump(model, "iris_model.joblib")
# Out:
# ['iris_model.joblib']

# %%
model = joblib.load("iris_model.joblib")

# %%
# Example input values for prediction (Sepal Length, Sepal Width, Petal Length, Petal Width)
example_input = [[5.1, 3.5, 1.4, 0.2]]
# Make the prediction
predictions = model.predict(example_input) # Changed sepal_length to example_input

# Output the prediction
print(predictions[0])  # This will give you the predicted class (e.g., 0, 1, or 2)
# Out:
# 0
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
